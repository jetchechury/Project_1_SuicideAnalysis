# %%
# Import dependencies
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Read in veteran suicide by sex file
vet_suicide_sex = "../Project_1_Team_2/Veteran Suicides by Sex.csv"
vet_suicide_df = pd.read_csv(vet_suicide_sex)
vet_suicide_df.head()
# Out:
#    Year   Region     State  Total  Male  Female
# 0  2005  Midwest  Illinois    190   180      10
# 1  2005  Midwest   Indiana    142   130      12
# 2  2005  Midwest      Iowa     65    60       5
# 3  2005  Midwest    Kansas     70    60      10
# 4  2005  Midwest  Michigan    187   180       7

# %%
vet_groupby = vet_suicide_df.groupby(["Region","Year"])
vet_groupby_sum = vet_groupby.sum()
vet_groupby_sum.head()
# Out:
#               Total  Male  Female
# Region  Year
# Midwest 2005   1374  1280      94
#         2006   1314  1220      94
#         2007   1278  1180      98
#         2008   1301  1187     114
#         2009   1289  1157     132

# %%
# read in suicide by age file
vet_suicide_age = "../Project_1_Team_2/Suicides by Age.csv"
vet_age_df = pd.read_csv(vet_suicide_age)
vet_age_df.head()
# Out:
#    Year Geographic\nRegion,\nBased on\nstate of\ndeath State of Death  \
# 0  2005                                     Total U.S.     Total U.S.
# 1  2005                                     Total U.S.     Total U.S.
# 2  2005                                     Total U.S.     Total U.S.
# 3  2005                                     Total U.S.     Total U.S.
# 4  2005                                     Total U.S.     Total U.S.
#
#   Age\nGroup Veteran\nSuicides Veteran\nSuicide\nRate\nper\n100,000  \
# 0      Total             5,797                                 23.9
# 1      18-34               544                                 25.2
# 2      35-54             2,063                                 29.0
# 3      55-74             1,868                                 18.7
# 4        75+             1,319                                 26.3
#
#   General\nPopulation\nSuicides General\nPopulation\nRate per\n100,000
# 0                        31,610                                   14.7
# 1                         8,455                                   13.1
# 2                        13,541                                   15.9
# 3                         6,554                                   13.5
# 4                         3,060                                   18.7

# %%
# dropping state rows
vet_age_df2 = vet_age_df.loc[vet_age_df["State of Death"].isin(["Total U.S.","All"])]
vet_age_df2.head(20)
# Out:
#      Year Geographic\nRegion,\nBased on\nstate of\ndeath State of Death  \
# 0    2005                                     Total U.S.     Total U.S.
# 1    2005                                     Total U.S.     Total U.S.
# 2    2005                                     Total U.S.     Total U.S.
# 3    2005                                     Total U.S.     Total U.S.
# 4    2005                                     Total U.S.     Total U.S.
# 5    2005                                      Northeast            All
# 6    2005                                      Northeast            All
# 7    2005                                      Northeast            All
# 8    2005                                      Northeast            All
# 9    2005                                      Northeast            All
# 55   2005                                        Midwest            All
# 56   2005                                        Midwest            All
# 57   2005                                        Midwest            All
# 58   2005                                        Midwest            All
# 59   2005                                        Midwest            All
# 125  2005                                          South            All
# 126  2005                                          South            All
# 127  2005                                          South            All
# 128  2005                                          South            All
# 129  2005                                          South            All
#
#     Age\nGroup Veteran\nSuicides Veteran\nSuicide\nRate\nper\n100,000  \
# 0        Total             5,797                                 23.9
# 1        18-34               544                                 25.2
# 2        35-54             2,063                                 29.0
# 3        55-74             1,868                                 18.7
# 4          75+             1,319                                 26.3
# 5        Total               698                                 17.6
# 6        18-34                43                                 17.3
# 7        35-54               233                                 23.8
# 8        55-74               238                                 14.1
# 9          75+               184                                 17.6
# 55       Total             1,374                                 25.3
# 56       18-34               120                                 28.6
# 57       35-54               512                                 33.2
# 58       55-74               445                                 19.4
# 59         75+               296                                 25.1
# 125      Total             2,312                                 24.3
# 126      18-34               241                                 24.5
# 127      35-54               817                                 27.2
# 128      55-74               740                                 19.5
# 129        75+               513                                 29.5
#
#     General\nPopulation\nSuicides General\nPopulation\nRate per\n100,000
# 0                          31,610                                   14.7
# 1                           8,455                                   13.1
# 2                          13,541                                   15.9
# 3                           6,554                                   13.5
# 4                           3,060                                   18.7
# 5                           4,298                                   10.7
# 6                           1,096                                    9.9
# 7                           1,891                                   11.6
# 8                             874                                    9.4
# 9                             437                                   12.3
# 55                          7,029                                   14.6
# 56                          1,974                                   13.8
# 57                          3,084                                   16.2
# 58                          1,367                                   12.7
# 59                            604                                   15.7
# 125                        12,285                                   15.8
# 126                         3,253                                   13.8
# 127                         5,219                                   17.2
# 128                         2,671                                   14.9
# 129                         1,142                                   20.3

# %%
# read in suicide by method file
vet_method = "../Project_1_Team_2/Suicides by Method.csv"
vet_method_df = pd.read_csv(vet_method)
vet_method_df.head()
# Out:
#    Year Geographic\nRegion State of Death    Group Method         Method  \
# 0  2005         Total U.S.            All  Veteran Method    Suffocation
# 1  2005         Total U.S.            All  Veteran Method      Poisoning
# 2  2005         Total U.S.            All  Veteran Method       Firearms
# 3  2005         Total U.S.            All  Veteran Method  Other Suicide
# 4  2005          Northeast            All  Veteran Method    Suffocation
#
#   Suicides Group\nPercentage
# 0      786              13.6
# 1      757              13.1
# 2    3,925              67.7
# 3      329               5.7
# 4      129              18.5

# %%
# dropping state rows
vet_method_df2 = vet_method_df.loc[vet_method_df["State of Death"]=="All"]
vet_method_df2.head(20)
# Out:
#      Year Geographic\nRegion State of Death    Group Method         Method  \
# 0    2005         Total U.S.            All  Veteran Method    Suffocation
# 1    2005         Total U.S.            All  Veteran Method      Poisoning
# 2    2005         Total U.S.            All  Veteran Method       Firearms
# 3    2005         Total U.S.            All  Veteran Method  Other Suicide
# 4    2005          Northeast            All  Veteran Method    Suffocation
# 5    2005          Northeast            All  Veteran Method      Poisoning
# 6    2005          Northeast            All  Veteran Method       Firearms
# 7    2005          Northeast            All  Veteran Method  Other Suicide
# 29   2005            Midwest            All  Veteran Method    Suffocation
# 30   2005            Midwest            All  Veteran Method      Poisoning
# 31   2005            Midwest            All  Veteran Method       Firearms
# 32   2005            Midwest            All  Veteran Method  Other Suicide
# 66   2005              South            All  Veteran Method    Suffocation
# 67   2005              South            All  Veteran Method      Poisoning
# 68   2005              South            All  Veteran Method       Firearms
# 69   2005              South            All  Veteran Method  Other Suicide
# 115  2005               West            All  Veteran Method    Suffocation
# 116  2005               West            All  Veteran Method      Poisoning
# 117  2005               West            All  Veteran Method       Firearms
# 118  2005               West            All  Veteran Method  Other Suicide
#
#     Suicides Group\nPercentage
# 0        786              13.6
# 1        757              13.1
# 2      3,925              67.7
# 3        329               5.7
# 4        129              18.5
# 5         66               9.5
# 6        447              64.0
# 7         56               8.0
# 29       214              15.6
# 30       209              15.2
# 31       883              64.3
# 32        68               4.9
# 66       261              11.3
# 67       267              11.5
# 68     1,661              71.8
# 69       123               5.3
# 115      182              12.9
# 116      215              15.2
# 117      934              66.1
# 118       82               5.8

# %%
# read female_suicide_method file and clean the data
female_suicide_method = "../Project_1_Team_2/female_suicide_methods.csv"
female_suicide_method_df = pd.read_csv(female_suicide_method)
female_suicide_method_df = female_suicide_method_df.drop(columns = ['Percent'])
female_suicide_method_df.head()
# Out:
#   Cause of Death  Deaths          State  Year      Sex    Age Group
# 0      Poisoning    2601  United States  2005  Females  Ages 18-85+
# 1        Firearm    2030  United States  2005  Females  Ages 18-85+
# 2    Suffocation    1212  United States  2005  Females  Ages 18-85+
# 3           Fall     182  United States  2005  Females  Ages 18-85+
# 4       Drowning     117  United States  2005  Females  Ages 18-85+

# %%
# read male_suicide_method file and clean the data
male_suicide_method = "../Project_1_Team_2/male_suicide_methods.csv"
male_suicide_method_df = pd.read_csv(male_suicide_method)
male_suicide_method_df.head()
male_suicide_method_df = male_suicide_method_df.drop(columns=['Last Year', 'Percent','Race/Ethnicty','Age Group'])
male_suicide_method_df = male_suicide_method_df.rename(columns ={'First Year': 'Year'})
male_suicide_method_df.head()
# Out:
#   Cause of Death  Deaths          State  Year    Sex
# 0        Firearm   14559  United States  2005  Males
# 1    Suffocation    5528  United States  2005  Males
# 2      Poisoning    3082  United States  2005  Males
# 3           Fall     489  United States  2005  Males
# 4     Cut/pierce     486  United States  2005  Males

# %%
#Merge , clean and rename dataframe
general_population_suicide_method = pd.merge(male_suicide_method_df,female_suicide_method_df, 
                                             on=['Cause of Death', 'Year','State'],
                                             suffixes=('_male', '_female'))

general_population_suicide_method['Deaths'] = general_population_suicide_method['Deaths_male'] + general_population_suicide_method['Deaths_female']
general_population_suicide_method.head()
# Out:
#   Cause of Death  Deaths_male          State  Year Sex_male  Deaths_female  \
# 0        Firearm        14559  United States  2005    Males           2030
# 1    Suffocation         5528  United States  2005    Males           1212
# 2      Poisoning         3082  United States  2005    Males           2601
# 3           Fall          489  United States  2005    Males            182
# 4     Cut/pierce          486  United States  2005    Males            103
#
#   Sex_female    Age Group  Deaths
# 0    Females  Ages 18-85+   16589
# 1    Females  Ages 18-85+    6740
# 2    Females  Ages 18-85+    5683
# 3    Females  Ages 18-85+     671
# 4    Females  Ages 18-85+     589

# %%
general_population_suicide_method = general_population_suicide_method.drop(columns = ['Deaths_male','Sex_male','Deaths_female','Sex_female'])
general_population_suicide_method.head()
# Out:
#   Cause of Death          State  Year    Age Group  Deaths
# 0        Firearm  United States  2005  Ages 18-85+   16589
# 1    Suffocation  United States  2005  Ages 18-85+    6740
# 2      Poisoning  United States  2005  Ages 18-85+    5683
# 3           Fall  United States  2005  Ages 18-85+     671
# 4     Cut/pierce  United States  2005  Ages 18-85+     589

# %%
#Calculate percentage
general_population_suicide_method_group = general_population_suicide_method.groupby(["State","Year"]).sum()
general_population_suicide_method_group= general_population_suicide_method_group.rename(columns ={'Deaths': 'Total Deaths'})
general_population_suicide_method_group.reset_index()

general_population_suicide_method_C = pd.merge(general_population_suicide_method,general_population_suicide_method_group, 
                                             on=['State', 'Year'])
        
general_population_suicide_method_C.head(20)
# Out:
#                Cause of Death          State  Year    Age Group  Deaths  \
# 0                     Firearm  United States  2005  Ages 18-85+   16589
# 1                 Suffocation  United States  2005  Ages 18-85+    6740
# 2                   Poisoning  United States  2005  Ages 18-85+    5683
# 3                        Fall  United States  2005  Ages 18-85+     671
# 4                  Cut/pierce  United States  2005  Ages 18-85+     589
# 5   Other Spec., classifiable  United States  2005  Ages 18-85+     318
# 6                    Drowning  United States  2005  Ages 18-85+     372
# 7            Other Spec., NEC  United States  2005  Ages 18-85+     223
# 8                 Unspecified  United States  2005  Ages 18-85+     164
# 9                   Fire/burn  United States  2005  Ages 18-85+     157
# 10    Transportation- Related  United States  2005  Ages 18-85+     104
# 11                    Firearm      Northeast  2005  Ages 18-85+    1788
# 12                Suffocation      Northeast  2005  Ages 18-85+    1235
# 13                  Poisoning      Northeast  2005  Ages 18-85+     744
# 14                       Fall      Northeast  2005  Ages 18-85+     178
# 15                 Cut/pierce      Northeast  2005  Ages 18-85+     114
# 16  Other Spec., classifiable      Northeast  2005  Ages 18-85+      80
# 17                   Drowning      Northeast  2005  Ages 18-85+      72
# 18                  Fire/burn      Northeast  2005  Ages 18-85+      32
# 19           Other Spec., NEC      Northeast  2005  Ages 18-85+      30
#
#     Total Deaths
# 0          31610
# 1          31610
# 2          31610
# 3          31610
# 4          31610
# 5          31610
# 6          31610
# 7          31610
# 8          31610
# 9          31610
# 10         31610
# 11          4298
# 12          4298
# 13          4298
# 14          4298
# 15          4298
# 16          4298
# 17          4298
# 18          4298
# 19          4298

# %%
general_population_suicide_method_C['Percent']=round(general_population_suicide_method_C['Deaths']/general_population_suicide_method_C['Total Deaths']*100,2) 
general_population_suicide_method_C.head()
# Out:
#   Cause of Death          State  Year    Age Group  Deaths  Total Deaths  \
# 0        Firearm  United States  2005  Ages 18-85+   16589         31610
# 1    Suffocation  United States  2005  Ages 18-85+    6740         31610
# 2      Poisoning  United States  2005  Ages 18-85+    5683         31610
# 3           Fall  United States  2005  Ages 18-85+     671         31610
# 4     Cut/pierce  United States  2005  Ages 18-85+     589         31610
#
#    Percent
# 0    52.48
# 1    21.32
# 2    17.98
# 3     2.12
# 4     1.86

# %%
# save the general_population_suicide_method data to csv
# general_population_suicide_method_C.to_csv('../Project_1_Team_2/general_population_suicide_methods.csv',index=False)

# %%
# creating bar graph to show various methods used
# prepare data
years = [2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]
vetFirearm = np.array([67.7,67.4,65.9,65.5,67.5,67.6,67.2,67.3,68.1,67.1,67.3,69.4])
vetOther = np.array([5.7,5.9,5.7,5.2,5.6,4.9,5.3,5.6,5.4,4.8,5.7,5.1])
vetPoison = np.array([13.1,12.6,13.0,13.5,12.4,13.1,12.1,11.8,11.2,11.6,11.2,10.6])
vetSuffocation = np.array([13.6,14.1,15.4,15.8,14.5,14.4,15.3,15.3,15.3,16.6,15.8,15])
civFirearm = np.array([52.48,51.04,50.44,50.97,51.15,50.91,50.91,51.25,51.84,50.28,50.13,51.36])
civPoison = np.array([17.98,18.73,18.66,18.22,17.73,17.53,16.96,16.97,16.51,16.25,15.73,15.25])
civOther = np.array([8.22,8.52,7.96,7.81,7.57,7.56,7.78,7.78,8.05,7.59,7.97,8.28])
civSuffocation = np.array([21.32,21.71,22.94,22.99,23.55,23.99,24.34,24.02,23.6,25.87,26.16,25.11])
ind = [x for x, _ in enumerate(years)]

# plot the data
# Civilan Graph
plt.bar(ind,civFirearm,label="Firearm Deaths(Civ)")
plt.bar(ind,civOther,label="Suicides(Other)(Civ)",bottom=civFirearm)
plt.bar(ind,civPoison,label="Poison Deaths(Civ)",bottom=civOther+civFirearm)
plt.bar(ind,civSuffocation,label="Suffocation Deaths(Civ)",bottom=civPoison+civOther+civFirearm)

# Labels
plt.ylabel('Deaths by %')
plt.xlabel('Year')
plt.title('Civilian Deaths by Method')
plt.xticks(ind,years)
plt.legend(loc="best")

# show graph
plt.show()

# Save Figure
plt.savefig("../Project_1_Team_2/Method_Civ.png")

# %%
# plot the data
# Veteran Graph
plt.bar(ind,vetFirearm,label="Firearm Deaths(Vet)")
plt.bar(ind,vetOther,label="Suicides(Other)(Vet)",bottom=vetFirearm)
plt.bar(ind,vetPoison,label="Poison Deaths(Vet)",bottom=vetOther+vetFirearm)
plt.bar(ind,vetSuffocation,label="Suffocation Deaths(Vet)",bottom=vetPoison+vetOther+vetFirearm)

# Labels
plt.ylabel('Deaths by %')
plt.xlabel('Year')
plt.title('Veteran Deaths by Method')
plt.xticks(ind,years)
plt.legend(loc="best")

# show graph
plt.show()

# Save Figure
plt.savefig("../Project_1_Team_2/Method_Vet.png")

# %%
# Line Graph to show percentage of suicides between civilian and veteran between 2005 - 2016
# prepare data
x_axis=np.arange(2005,2017,1)
civ_points=[14.7,14.4,14.9,15.3,15.5,16.0,16.2,16.5,16.5,17.0,17.3,17.5]
vet_points=[23.9,24.0,25.3,27.0,27.3,27.5,27.7,27.9,28.7,30.0,30.5,30.1]

# Labels
plt.ylabel('Deaths by %')
plt.xlabel('Year')
plt.title('2005 - 2016 Suicides by Percentage')
plt.xticks(x_axis)

# Plot Graph
plt.plot(x_axis,civ_points,linewidth=2,marker="o",color="blue")
plt.plot(x_axis,vet_points,linewidth=2,marker="o",color="red")
plt.legend(["Civilian Suicides","Veteran Suicides"],loc="best")

# Show Graph
plt.show()

# Save Figure
plt.savefig("../Project_1_Team_2/Suicides_Line_Graph.png")
# Out:
# <img src="data:image/png;base64,..." width="639.8031069619097">
